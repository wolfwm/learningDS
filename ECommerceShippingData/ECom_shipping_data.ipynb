# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
ecsd = pd.read_csv("Train.csv")

# %%
ecsd
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# 2                    2                  183                4
# 3                    3                  176                4
# 4                    2                  184                3
# ...                ...                  ...              ...
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                    low      F                44           1233
# 1                    low      M                59           3088
# 2                    low      M                48           3374
# 3                 medium      M                10           1177
# 4                 medium      F                46           2484
# ...                  ...    ...               ...            ...
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 10994                    1
# 10995                    0
# 10996                    0
# 10997                    0
# 10998                    0
#
# [10999 rows x 12 columns]

# %%
ecsd.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %%
ecsd[(ecsd.Warehouse_block == "D") & (ecsd.Mode_of_Shipment == "Ship")]

# %%
ecsd[ecsd.Warehouse_block == "D"].groupby("Warehouse_block")["Warehouse_block"].count()

# %%
pd.to_numeric(ecsd.Warehouse_block, errors='coerce')

# %% [markdown]
# ==============================

# %% [markdown]
# Quantas compras tem um customer rating de 5?

# %%
ecsd[ecsd.Customer_rating == 5].groupby("Customer_rating")["Customer_rating"].count()

# %% [markdown]
# Quantas compras tem mais de duas compras anteriores?

# %%
ecsd[ecsd.Prior_purchases > 2].groupby("Prior_purchases")["Prior_purchases"].count().sum()

# %% [markdown]
# Quantas compras tem importância alta ou baixa?

# %%
ecsd[(ecsd.Product_importance == "low") | (ecsd.Product_importance == "high")].groupby("Product_importance")["Product_importance"].count().sum()

# %% [markdown]
# Qual a quantidade média de customer care calls das compras?

# %%
ecsd["Customer_care_calls"].mean()

# %% [markdown]
# Qual o custo médio dos produtos das compras?

# %%
ecsd["Cost_of_the_Product"].mean()

# %% [markdown]
# Qual o desvio padrão do custo dos produtos das compras?

# %%
ecsd["Cost_of_the_Product"].std()

# %% [markdown]
# Existem compras com custos outliers?

# %%
ecsd.groupby('Cost_of_the_Product')['Cost_of_the_Product'].count()

# %% [markdown]
# Quais são os 1Q e 3Q dos custos?

# %%
ecsd['Cost_of_the_Product'].quantile(0.25)

# %%
ecsd['Cost_of_the_Product'].quantile(0.75)

# %% [markdown]
# ---------------

# %% [markdown]
# Manipulação de dados:
#     *Pandas
#         -Selecionar Colunas

# %%
ecsd['Cost_of_the_Product']
# Out:
# 0        177
# 1        216
# 2        183
# 3        176
# 4        184
#         ...
# 10994    252
# 10995    232
# 10996    242
# 10997    223
# 10998    155
# Name: Cost_of_the_Product, Length: 10999, dtype: int64

# %% [markdown]
#         -Filtrar Linhas

# %%
ecsd[ecsd['Cost_of_the_Product'] <= 100]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 151      152               F           Flight                    5
# 152      153               A           Flight                    3
# 431      432               F             Ship                    4
# 821      822               F           Flight                    2
# 974      975               A           Flight                    5
# 1038    1039               D             Ship                    4
# 1207    1208               F             Road                    3
# 1435    1436               F             Ship                    6
# 2223    2224               B             Ship                    4
# 2418    2419               D             Ship                    5
# 2756    2757               A           Flight                    3
# 2783    2784               F             Ship                    3
# 2802    2803               D             Ship                    3
# 2894    2895               A             Ship                    3
# 3254    3255               A             Ship                    3
# 3475    3476               F             Ship                    6
# 3611    3612               F             Ship                    2
# 4031    4032               F             Ship                    6
# 4062    4063               D             Ship                    6
# 4130    4131               A             Ship                    6
# 4158    4159               D             Ship                    2
# 5145    5146               B             Ship                    5
# 5844    5845               D             Ship                    3
# 5907    5908               B           Flight                    4
# 6723    6724               B           Flight                    5
# 6768    6769               D             Ship                    4
# 7082    7083               A             Ship                    4
# 7121    7122               F           Flight                    4
# 7238    7239               A             Road                    3
# 7892    7893               A             Ship                    6
# 7929    7930               B             Road                    4
# 7975    7976               F             Ship                    4
# 8513    8514               F             Ship                    6
# 8953    8954               F             Ship                    2
# 9485    9486               F             Ship                    3
# 9727    9728               F           Flight                    5
# 9783    9784               B             Ship                    4
# 10322  10323               A             Ship                    2
# 10615  10616               F             Ship                    3
# 10622  10623               A             Ship                    5
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 151                  3                   98                5
# 152                  4                   97                4
# 431                  2                   96                3
# 821                  1                   98                3
# 974                  3                   96                4
# 1038                 3                   97                2
# 1207                 1                  100                3
# 1435                 5                  100                4
# 2223                 1                   97                2
# 2418                 2                   96                2
# 2756                 5                   98                3
# 2783                 2                   98                3
# 2802                 3                   99                3
# 2894                 4                   98                2
# 3254                 4                  100                3
# 3475                 4                  100                5
# 3611                 1                  100                3
# 4031                 5                   98                3
# 4062                 3                   98                3
# 4130                 3                  100                4
# 4158                 4                  100                4
# 5145                 4                   97                6
# 5844                 4                   98                3
# 5907                 3                   96                4
# 6723                 4                   99                2
# 6768                 1                  100                6
# 7082                 5                   98                4
# 7121                 5                   98                4
# 7238                 3                   99                5
# 7892                 2                   99                3
# 7929                 4                   97                6
# 7975                 3                   97                6
# 8513                 3                   98                6
# 8953                 2                   98                5
# 9485                 5                   98                3
# 9727                 4                   97                3
# 9783                 3                   99                6
# 10322                1                   96                2
# 10615                2                  100                4
# 10622                5                   98                2
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 151               medium      M                44           1269
# 152                  low      M                32           1238
# 431                  low      M                22           1294
# 821                  low      F                29           1806
# 974               medium      F                12           1655
# 1038                 low      M                26           1598
# 1207                 low      F                17           1129
# 1435              medium      F                 3           1440
# 2223                high      M                15           1836
# 2418                 low      F                50           1186
# 2756              medium      F                48           1635
# 2783              medium      F                60           1057
# 2802                high      M                63           1223
# 2894                 low      F                32           1539
# 3254              medium      M                 4           4191
# 3475                 low      F                 7           5668
# 3611                 low      M                 1           5776
# 4031                 low      F                 8           5946
# 4062                 low      F                 8           4651
# 4130                 low      M                 3           5756
# 4158                 low      M                 3           5398
# 5145                high      M                 7           5509
# 5844                 low      M                 5           4432
# 5907              medium      M                 1           4984
# 6723                high      F                 4           4259
# 6768              medium      M                 6           5841
# 7082                 low      F                 5           4643
# 7121                 low      M                 5           5188
# 7238              medium      M                 9           5470
# 7892                 low      M                 8           5872
# 7929                 low      M                 4           5801
# 7975                 low      F                 4           4375
# 8513                 low      M                 9           4787
# 8953              medium      M                10           4368
# 9485              medium      F                 3           5553
# 9727              medium      F                 8           4577
# 9783              medium      M                 9           5903
# 10322               high      F                 9           4449
# 10615                low      F                10           5163
# 10622             medium      M                 2           4125
#
#        Reached.on.Time_Y.N
# 151                      1
# 152                      1
# 431                      1
# 821                      1
# 974                      1
# 1038                     1
# 1207                     1
# 1435                     1
# 2223                     1
# 2418                     1
# 2756                     1
# 2783                     1
# 2802                     1
# 2894                     1
# 3254                     0
# 3475                     1
# 3611                     1
# 4031                     0
# 4062                     1
# 4130                     0
# 4158                     0
# 5145                     1
# 5844                     0
# 5907                     1
# 6723                     0
# 6768                     0
# 7082                     0
# 7121                     0
# 7238                     0
# 7892                     0
# 7929                     0
# 7975                     0
# 8513                     1
# 8953                     0
# 9485                     1
# 9727                     0
# 9783                     0
# 10322                    1
# 10615                    0
# 10622                    1

# %% [markdown]
#         -Agregação(Group by)

# %%
ecsd.groupby('Mode_of_Shipment')['Mode_of_Shipment'].count()
# Out:
# Mode_of_Shipment
# Flight    1777
# Road      1760
# Ship      7462
# Name: Mode_of_Shipment, dtype: int64

# %% [markdown]
#         -Funções Apply Lambda

# %% [markdown]
#         -União de Dados (Merge, Concat)

# %% [markdown]
# Análise de Dados:
#     *Seaborn e Matplotlib
#         -Gráficos (Barras, Linhas, Empilhado)

# %% [markdown]
#         -Correlações

# %% [markdown]
#         -Validação de Hipóteses

# %% [markdown]
# ---------------

# %% [markdown]
# Gerar gráficos e apresentar para pessoas perguntando se está claro pelo gráfico a resposta.
